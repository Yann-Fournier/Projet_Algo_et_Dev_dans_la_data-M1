# %%
from GetData import GetData # Importation de la classe GetData depuis GetData.py
from Utils import rsi, macd, stochastique, bollinger_bands, moyenne_mobile # Importation des fonctions d'indicateurs techniques depuis Utils.py
from Utils import simple_plot, plot_rsi, plot_macd, plot_stochastique, plot_bollinger_bands, plot_moyenne_mobile # Importation des fonctions de visualisation depuis Utils.py

# %%
BTC_USDT_1D = GetData(
    exchange="binance",
    pair="BTC/USDT",
    tf="1d",
)
await BTC_USDT_1D.download_data()

print(BTC_USDT_1D.data.shape)
BTC_USDT_1D.data.head()
# Out:
# Récupération pour la paire BTC/USDT en timeframe 1d sur l'exchange binance
#   0%|          | 0/4 [00:00<?, ?it/s]
# (3168, 5)
#                open     high      low    close       volume
# date
# 2017-08-17  4261.48  4485.39  4200.74  4285.08   795.150377
# 2017-08-18  4285.08  4371.52  3938.77  4108.37  1199.888264
# 2017-08-19  4108.37  4184.69  3850.00  4139.98   381.309763
# 2017-08-20  4120.98  4211.08  4032.62  4086.29   467.083022
# 2017-08-21  4069.13  4119.62  3911.79  4016.00   691.743060

# %% [markdown]
# ### Ajout des indicateurs dans le dataframe
# ---

# %%
BTC_USDT_1D.data = rsi(BTC_USDT_1D.data)
BTC_USDT_1D.data = macd(BTC_USDT_1D.data)
BTC_USDT_1D.data = stochastique(BTC_USDT_1D.data)
BTC_USDT_1D.data = bollinger_bands(BTC_USDT_1D.data)
BTC_USDT_1D.data = moyenne_mobile(BTC_USDT_1D.data)

# %%
print(BTC_USDT_1D.data.shape)
BTC_USDT_1D.data.tail()
# Out:
# (3168, 17)
#                 open      high  ...          sma9         sma21
# date                            ...
# 2026-04-15  74131.55  75425.00  ...  72765.387778  69750.207619
# 2026-04-16  74809.99  75534.76  ...  73124.284444  70051.825714
# 2026-04-17  75154.28  78333.00  ...  73791.181111  70559.669524
# 2026-04-18  77072.01  77420.08  ...  74224.935556  71003.228095
# 2026-04-19  75691.76  75847.42  ...  74460.403333  71435.179524
#
# [5 rows x 17 columns]

# %% [markdown]
# ### Graphique
# ---

# %%
simple_plot(BTC_USDT_1D.data, BTC_USDT_1D.pair + " - " + BTC_USDT_1D.tf)
# Out:
# <Mpf_Figure size 2000x1500 with 1 Axes>

# %%
plot_rsi(BTC_USDT_1D.data, BTC_USDT_1D.pair + " - " + BTC_USDT_1D.tf)
# Out:
# <Mpf_Figure size 2000x1500 with 2 Axes>

# %%
plot_macd(BTC_USDT_1D.data, BTC_USDT_1D.pair + " - " + BTC_USDT_1D.tf)
# Out:
# <Mpf_Figure size 2000x1500 with 2 Axes>

# %%
plot_stochastique(BTC_USDT_1D.data, BTC_USDT_1D.pair + " - " + BTC_USDT_1D.tf)
# Out:
# <Mpf_Figure size 2000x1500 with 2 Axes>

# %%
plot_bollinger_bands(BTC_USDT_1D.data, BTC_USDT_1D.pair + " - " + BTC_USDT_1D.tf)
# Out:
# <Mpf_Figure size 2000x1500 with 1 Axes>

# %%
plot_moyenne_mobile(BTC_USDT_1D.data, BTC_USDT_1D.pair + " - " + BTC_USDT_1D.tf)
# Out:
# <Mpf_Figure size 2000x1500 with 1 Axes>
